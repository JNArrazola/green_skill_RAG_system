# %% [markdown]
# # Forecasting results

# %% [markdown]
# ## Model Configuration for Sequence Length 6, Prediction Length 3
# | Parameter | Value |
# |-----------|-------|
# | Learning Rate | 0.0001 |
# | Epoch | 20 |
# | Optimizer | Adam |
# | Loss Function | MSE |
# | Sequence Length | 6 |
# | Prediction Length | 3 |
# | Features | 274 |

# %% [markdown]
# ### Results for Sequence Length 6, Prediction Length 3
# | Model | MAE | RMSE | sMAPE | rRMSE |
# |-------|-----|------|-------|-------|
# | LightTS | 1.5983 | 4.3663 | 67.1700 | 42.0733 |
# | PatchTST | 1.6327 | 4.6902 | 74.6221 | 45.1943 |
# | Reformer | 0.6895 | 2.1401 | 57.6583 | 20.6216 |
# | Informer | 0.6512 | 1.9216 | 57.4746 | 18.5160 |
# | FEDformer | 0.5891 | 1.7986 | 56.7796 | 17.3310 |
# | DLinear | 1.9160 | 5.6331 | 73.4665 | 54.2802 |
# | TiDE | 2.2222 | 6.4454 | 76.7664 | 62.1073 |
# | Nonstationary_Transformer | 0.9106 | 2.7796 | 63.6394 | 26.7838 |
# | SegRNN | 1.7928 | 5.1674 | 69.9021 | 49.7922 |
# | FreTS | 1.2309 | 3.0946 | 64.5397 | 29.8190 |
# | TSMixer | 1.5382 | 4.4619 | 69.5459 | 42.9941 |
# | Crossformer | 1.1274 | 2.8329 | 64.6988 | 27.2974 |
# | Koopa | 1.8337 | 5.3223 | 73.4501 | 51.2856 |
# | Autoformer | 0.7611 | 2.1966 | 58.9506 | 21.1662 |
# | CHGH | 1.6045 | 4.7213 | 68.7706 | 45.4939 |
# | Transformer | 0.6057 | 1.6401 | 57.1570 | 15.8035 |
# | LSTM | 1.5369 | 4.4880 | 66.6478 | 43.2456 |

# %% [markdown]
# # Metrics for Sequence Length 6, Prediction Length 3 (Normalized Data)
# | Model | MAE | RMSE | sMAPE | rRMSE |
# |-------|---------------------|----------------------|---------------------|---------------------|
# | LightTS | 7.429467950714752e-05 | 0.0001981522364076227 | 67.89131927490234 | 36.92145538330078 |
# | PatchTST | 7.753988029435277e-05 | 0.0002081772981910035 | 71.3448257446289 | 38.78941345214844 |
# | Reformer | 3.162921348121017e-05 | 7.991403253981844e-05 | 57.381324768066406 | 14.890280723571777 |
# | Informer | 3.0283103114925325e-05 | 7.003886275924742e-05 | 57.26725387573242 | 13.050251960754395 |
# | FEDformer | 2.6722198526840657e-05 | 6.551709520863369e-05 | 56.738155364990234 | 12.207717895507812 |
# | DLinear | 8.017937943805009e-05 | 0.00021378144447226077 | 71.4923324584961 | 39.83362579345703 |
# | TiDE | 8.945051376940683e-05 | 0.00022750016069039702 | 74.33602142333984 | 42.38981628417969 |
# | Nonstationary_Transformer | 4.382312181405723e-05 | 0.0001229818444699049 | 63.220943450927734 | 22.915050506591797 |
# | SegRNN | 7.767612987663597e-05 | 0.00020429358119145036 | 67.83625793457031 | 38.065765380859375 |
# | FreTS | 6.968795059947297e-05 | 0.00017097122326958925 | 64.90921020507812 | 31.856849670410156 |
# | TSMixer | 6.705423584207892e-05 | 0.00017847178969532251 | 67.88839721679688 | 33.25442123413086 |
# | Crossformer | 6.158019095892087e-05 | 0.00015798032109159976 | 64.12242126464844 | 29.43627166748047 |
# | Koopa | 7.777826249366626e-05 | 0.00021154737623874098 | 72.04963684082031 | 39.417354583740234 |
# | Autoformer | 3.828984699794091e-05 | 0.00010072392615256831 | 58.90266799926758 | 18.76776123046875 |
# | FiLM | 8.736708696233109e-05 | 0.00020062053226865828 | 68.05736541748047 | 37.381370544433594 |
# | CHGH | 6.63377286400646e-05 | 0.00017459220543969423 | 66.96202087402344 | 32.53154373168945 |
# | Transformer | 3.055121487705037e-05 | 8.281940972665325e-05 | 57.19368362426758 | 15.431634902954102 |
# | LSTM | 6.586814561160281e-05 | 0.00016750193026382476 | 64.92146301269531 | 31.21042251586914 |

# %% [markdown]
# ---
# ## Model Configuration for Sequence Length 4, Prediction Length 3
# | Parameter | Value |
# |-----------|-------|
# | Learning Rate | 0.0001 |
# | Epoch | 20 |
# | Optimizer | Adam |
# | Loss Function | MSE |
# | Sequence Length | 4 |
# | Prediction Length | 3 |
# | Features | 274 |

# %% [markdown]
# # Metric Results for Sequence Length 4, Prediction Length 3
# | Model | MAE | RMSE | sMAPE | rRMSE |
# |-------|-----|------|-------|-------|
# | Nonstationary_Transformer | 1.0094 | 3.0028 | 65.6742 | 28.9349 |
# | DLinear | 2.4798 | 7.3934 | 83.8470 | 71.2418 |
# | CHGH | 1.5419 | 4.5476 | 69.0094 | 43.8198 |
# | FEDformer | 0.5060 | 1.5138 | 56.2605 | 14.5864 |
# | Reformer | 0.5098 | 1.4642 | 56.0617 | 14.1087 |
# | TSMixer | 1.7361 | 5.2046 | 70.8791 | 50.1511 |
# | LSTM | 1.4780 | 4.2601 | 66.1784 | 41.0496 |
# | FreTS | 1.3293 | 3.4584 | 65.3960 | 33.3245 |
# | Transformer | 0.4832 | 1.2848 | 56.0317 | 12.3799 |
# | Autoformer | 0.6769 | 1.9190 | 58.3377 | 18.4909 |
# | Crossformer | 1.2804 | 3.2798 | 62.9654 | 31.6042 |
# | Informer | 0.5609 | 1.6287 | 56.9006 | 15.6936 |
# | TiDE | 2.1293 | 6.2177 | 73.0828 | 59.9131 |
# | Koopa | 2.0124 | 6.2063 | 73.8151 | 59.8032 |
# ---
# # Metric Results for **normalized** Sequence Length 4, Prediction Length 3
# | Model | MAE | RMSE | sMAPE | rRMSE |
# |-------|-----|------|-------|-------|
# | Nonstationary_Transformer | 4.8651720135239884e-05 | 0.00013630652392748743 | 65.204833984375 | 25.3978214263916 |
# | DLinear | 0.00010303108865628019 | 0.0002663518243934959 | 82.74266815185547 | 49.62900161743164 |
# | CHGH | 6.684595427941531e-05 | 0.00017479450616519898 | 66.58238983154297 | 32.569236755371094 |
# | FEDformer | 2.497724381100852e-05 | 5.9200079704169184e-05 | 56.294803619384766 | 11.030675888061523 |
# | Reformer | 2.5397184799658135e-05 | 6.633401062572375e-05 | 55.79774475097656 | 12.359931945800781 |
# | TSMixer | 6.572619895450771e-05 | 0.0001639349793549627 | 67.85658264160156 | 30.54579734802246 |
# | LSTM | 6.49740468361415e-05 | 0.0001656579115660861 | 64.69970703125 | 30.86682891845703 |
# | FreTS | 6.859038694528863e-05 | 0.00017322195344604552 | 65.1454849243164 | 32.27622985839844 |
# | FiLM | 8.843043906381354e-05 | 0.0002014288038481027 | 68.95430755615234 | 37.5319709777832 |
# | Transformer | 2.6083644115715288e-05 | 7.5391391874291e-05 | 56.07243347167969 | 14.047582626342773 |
# | Autoformer | 3.453325552982278e-05 | 8.392757445108145e-05 | 58.35493850708008 | 15.638118743896484 |
# | Crossformer | 6.479150761151686e-05 | 0.000164118580869399 | 63.450557708740234 | 30.580007553100586 |
# | Informer | 2.7863527066074312e-05 | 6.333399505820125e-05 | 56.88220977783203 | 11.800943374633789 |
# | TiDE | 8.380502549698576e-05 | 0.0002037155209109187 | 71.14419555664062 | 37.95805358886719 |
# | Koopa | 8.131320646498352e-05 | 0.00021906178153585643 | 72.79666900634766 | 40.817501068115234 |

# %% [markdown]
# ## Evaluation metrics
# To **evaluate** the performance of various benchmark models in job skill demand forecasting tasks, they are two selected metrics:
# * [MAE](https://en.wikipedia.org/wiki/Mean_absolute_error): It is calculated over $H$ observations using the formula:
# \begin{equation*}
# MAE = \frac{1}{H}\sum_{i=1}^{H}|y_i - \hat{y}_i|
# \end{equation*}
# * [RMSE](https://en.wikipedia.org/wiki/Root_mean_square_deviation): It is calculated as:
# \begin{equation*}
# RMSE = \sqrt{\frac{1}{H}\sum_{i=1}^{H}(y_i - \hat{y}_i)^2}
# \end{equation*}
# Both `MAE` and `RMSE` are scale-dependent metrics, which makes them unsuitable for comparison across different granularities. Additionally, these metrics are less sensitive to prediction errors at lower skill demand values.
#
# Therefore, they also applied:
# * [SMAPE](https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error): Which considers both the magnitude and direction of errors, making it suitable for comparing forecasts across different scales.
# \begin{equation*}
# SMAPE = \frac{2}{H}*\sum_{i = 1}^{H}\frac{|y_i - \hat{y}_i|}{|y_i| + |\hat{y}_i|}
# \end{equation*}
# * `RRMSE`: Measures the square root of the average of the squared percentage errors.
# \begin{equation*}
# RRMSE = \sqrt{\frac{\frac{1}{H}\sum_{i = 1}^{H}(y_i - \hat{y}_i)^2}{\sum_{i = 1}^{H}(\hat{y}_i)^2}}
# \end{equation*}

# %% [markdown]
# ---
